# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    Unnamed: 0                   City Country  Max Temp Current Description  \
# 0           6   Vila Franca Do Campo      PT     75.20     overcast clouds
# 1           8               Fairhope      US     82.06    scattered clouds
# 2          12  Sao Paulo De Olivenca      BR     84.72          light rain
# 3          13                  Kapaa      US     81.19          light rain
# 4          15                 Hirara      JP     82.89       broken clouds
#
#        Lat       Lng                           Hotel Name
# 0  37.7167  -25.4333                  Pestana Bahia Praia
# 1  30.5230  -87.9033      Hampton Inn Fairhope-Mobile Bay
# 2  -3.3783  -68.8725                                  NaN
# 3  22.0752 -159.3190  Sheraton Kauai Coconut Beach Resort
# 4  24.8000  125.2833       Hotel Atoll Emerald Miyakojima

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>

<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description}</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=.85)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#vacation_df.sort_values(by=['Country','City'])
#vacation_df.sort_values(by=['Country','City']).head(50)
vacation_df = vacation_df.dropna()

# %%
vacation_df.isnull().values.any()
# Out:
# False

# %%
vacation_df.sort_values(by=['Country','City']).head(50)
# Out:
#      Unnamed: 0                      City Country  Max Temp  \
# 123         388                The Valley      AI     87.66
# 70          216                 Catamarca      AR     76.77
# 145         448                   Rafaela      AR     79.00
# 193         591       Santiago Del Estero      AR     75.81
# 165         517                 Alyangula      AU     76.87
# 105         322                Oranjestad      AW     85.95
# 143         444                 Bathsheba      BB     86.61
# 141         439                     Dhaka      BD     84.18
# 179         560                     Nikki      BJ     76.77
# 44          143           Arraial Do Cabo      BR     75.16
# 60          178                  Belmonte      BR     79.30
# 121         380                     Borba      BR     89.13
# 124         389                  Cabedelo      BR     81.27
# 209         646                   Camapua      BR     80.69
# 12           51                   Camocim      BR     80.42
# 214         668                     Coari      BR     83.52
# 142         441                   Itarema      BR     79.70
# 103         316              Jacareacanga      BR     87.04
# 30          101                  Maragogi      BR     75.97
# 156         476               Morada Nova      BR     84.52
# 208         645                 Oriximina      BR     86.47
# 126         402                 Paranaiba      BR     87.10
# 160         502                 Piacabucu      BR     75.76
# 66          210                   Pitimbu      BR     81.19
# 184         569  Sao Gabriel Da Cachoeira      BR     81.50
# 188         577         Sao Joao Da Barra      BR     82.49
# 152         463        Sao Joao Dos Patos      BR     87.98
# 98          287                    Touros      BR     81.50
# 148         459                    Uruacu      BR     87.49
# 150         461                   Urucara      BR     85.75
# 155         472                Vila Velha      BR     80.94
# 85          250             Lac Du Bonnet      CA     78.58
# 112         365                 Sassandra      CI     76.80
# 36          122                    Avarua      CK     77.05
# 57          172                  Santiago      CL     79.18
# 40          132                    Maroua      CM     77.95
# 147         451                    Jieshi      CN     79.50
# 162         504                     Loudi      CN     78.69
# 113         366                    Pumiao      CN     77.40
# 86          253                Shenjiamen      CN     75.90
# 10           43                   Wanxian      CN     77.05
# 200         616                 Xiongzhou      CN     75.67
# 69          215                     Yulin      CN     75.92
# 91          269                Guantanamo      CU     83.77
# 65          207                     Praia      CV     81.14
# 39          130                Sao Filipe      CV     80.55
# 19           64              Puerto Ayora      EC     78.76
# 210         647                     Aswan      EG     83.50
# 185         572                 Port Said      EG     75.18
# 27           91                   Mayumba      GA     76.26
#
#     Current Description      Lat       Lng  \
# 123       broken clouds  18.2170  -63.0578
# 70            clear sky -28.4696  -65.7852
# 145           clear sky -31.2503  -61.4867
# 193           clear sky -27.7951  -64.2615
# 165       broken clouds -13.8483  136.4192
# 105    scattered clouds  12.5240  -70.0270
# 143    scattered clouds  13.2167  -59.5167
# 141                haze  23.7104   90.4074
# 179          few clouds   9.9401    3.2108
# 44        broken clouds -22.9661  -42.0278
# 60           few clouds -15.8631  -38.8828
# 121     overcast clouds  -4.3878  -59.5939
# 124          few clouds  -6.9811  -34.8339
# 209          light rain -19.5314  -54.0439
# 12        broken clouds  -2.9022  -40.8411
# 214     overcast clouds  -4.0850  -63.1414
# 142     overcast clouds  -2.9248  -39.9167
# 103     overcast clouds  -6.2222  -57.7528
# 30            clear sky  -9.0122  -35.2225
# 156       broken clouds  -5.1067  -38.3725
# 208     overcast clouds  -1.7656  -55.8661
# 126     overcast clouds -19.6772  -51.1908
# 160           clear sky -10.4056  -36.4344
# 66            clear sky  -7.4706  -34.8086
# 184     overcast clouds  -0.1303  -67.0892
# 188       broken clouds -21.6403  -41.0511
# 152     overcast clouds  -6.4950  -43.7022
# 98            clear sky  -5.1989  -35.4608
# 148     overcast clouds -14.5247  -49.1408
# 150       moderate rain  -2.5364  -57.7600
# 155    scattered clouds -20.3297  -40.2925
# 85        broken clouds  50.2536  -96.0612
# 112           clear sky   4.9500   -6.0833
# 36           few clouds -21.2078 -159.7750
# 57            clear sky -33.4569  -70.6483
# 40           light rain  10.5910   14.3159
# 147          few clouds  22.8134  115.8257
# 162          few clouds  27.7344  111.9944
# 113          light rain  22.7500  108.4833
# 86            clear sky  29.9576  122.2980
# 10            clear sky  30.8039  108.3897
# 200           clear sky  25.1167  114.3000
# 69           light rain  22.6333  110.1500
# 91      overcast clouds  20.1444  -75.2092
# 65           few clouds  14.9215  -23.5087
# 39           few clouds  14.8961  -24.4956
# 19        broken clouds  -0.7393  -90.3518
# 210           clear sky  24.0934   32.9070
# 185    scattered clouds  31.2565   32.2841
# 27      overcast clouds  -3.4320   10.6554
#
#                                    Hotel Name
# 123              CeBlue Villas & Beach Resort
# 70               Amerian Catamarca Park Hotel
# 145                      Parra Hotel & Suites
# 193                  Apartamentos Castelli 90
# 165                      Groote Eylandt Lodge
# 105          Divi Village Golf & Beach Resort
# 143                            Atlantis Hotel
# 141                          Main Hostel SSMC
# 179                                Hotel John
# 44                        Pousada Porto Praia
# 60                Pousada Monte Carmelo O Pão
# 121                         Hotel da Amazônia
# 124                             Hotel Pigalle
# 209                         Comercial Estrela
# 12                         Hotel Ilha do Amor
# 214                           HOTEL ALEX FLAT
# 142        Sea Lounge! Bar, Club & Restaurant
# 103                              Casa do Ian😎
# 30   Salinas do Maragogi All Inclusive Resort
# 156                          PIZZARIA MARIANA
# 208                        Pousada Tia Amélia
# 126                 Villa Rica Park Hotel GMR
# 160                            Piaçabuçu News
# 66                           Reserva do Abiaí
# 184  Alarne - Área De Lazer Do Alto Rio Negro
# 188                   Pousada Porto De Canoas
# 152             Montesino Hotel & Restaurante
# 98                            INN NEW HORIZON
# 148                             Cassius Hotel
# 150                      Pousada Maria Bonita
# 155                 Quality Suites Vila Velha
# 85                    Casey's Inn Motor Hotel
# 112                               la terrasse
# 36                               Paradise Inn
# 57                Che Lagarto Hostel Santiago
# 40                              Maroua Palace
# 147                              Yuehai Hotel
# 162                         Till Bright Hotel
# 113                    Mushang Boutique Hotel
# 86     Jinjiang Inn Zhoushan Putuo Shenjiamen
# 10              7Days Inn Chongqing Shiqiaopu
# 200                   Xinhewan Business Hotel
# 69                                     罗弟天海大厦
# 91                           Hotel Guantánamo
# 65                              LT Aparthotel
# 39                              Hotel Xaguate
# 19                  Finch Bay Galapagos Hotel
# 210                                 Nuba Nile
# 185                              Aracan Hotel
# 27                              LIKWALE LODGE

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
city1_temp = str(input("What is the start city for your trip? "))
city2_temp = str(input("What is the second city for your trip? "))
city3_temp = str(input("What is the third city for your trip? "))
city4_temp = str(input("What is the fourth city for your trip? "))
city5_temp = str(input("What is the end city (use start city} for last stage of your trip? "))
# Out:
# What is the start city for your trip? Jieshi
# What is the second city for your trip? Loudi
# What is the third city for your trip? Pumiao
# What is the fourth city for your trip? Yulin
# What is the end city (use start city} for last stage of your trip? Jieshi

# %%
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == city1_temp]
vacation_end = vacation_df.loc[vacation_df["City"] == city5_temp]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == city2_temp]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == city3_temp] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == city4_temp]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start= (vacation_start['Lat'].to_numpy()[0],vacation_start['Lng'].to_numpy()[0])
end = (vacation_end['Lat'].to_numpy()[0],vacation_end['Lng'].to_numpy()[0])
stop1 = (vacation_stop1['Lat'].to_numpy()[0],vacation_stop1['Lng'].to_numpy()[0])
stop2 = (vacation_stop2['Lat'].to_numpy()[0],vacation_stop2['Lng'].to_numpy()[0])
stop3 = (vacation_stop3['Lat'].to_numpy()[0],vacation_stop3['Lng'].to_numpy()[0])
end
# Out:
# (22.8134, 115.8257)

# %%
 #7. Create a direction layer map using the start and end latitude-longitude pairs,
    

# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

startend = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(startend)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.


#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start,vacation_stop1,vacation_stop2,vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    Unnamed: 0    City Country  Max Temp Current Description      Lat  \
# 0         451  Jieshi      CN     79.50          few clouds  22.8134
# 1         504   Loudi      CN     78.69          few clouds  27.7344
# 2         366  Pumiao      CN     77.40          light rain  22.7500
# 3         215   Yulin      CN     75.92          light rain  22.6333
#
#         Lng              Hotel Name
# 0  115.8257            Yuehai Hotel
# 1  111.9944       Till Bright Hotel
# 2  108.4833  Mushang Boutique Hotel
# 3  110.1500                  罗弟天海大厦

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=9.0)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
